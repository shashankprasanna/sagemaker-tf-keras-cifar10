# %% [markdown]
# #  TensorFlow Distributed Training with horovod

# %%
# %matplotlib inline
import os
import numpy as np
import sagemaker
from sagemaker.session import s3_input

sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# %%
from sagemaker.tensorflow import TensorFlow

hvd_instance_type = 'ml.p3.8xlarge'
hvd_instance_count = 2
hvd_processes_per_host = 4

distributions = {'mpi': {
                    'enabled': True,
                    'processes_per_host': hvd_processes_per_host,
                    'custom_mpi_options': '-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none'
                        }
                }

hyperparameters = {'epochs': 30, 'batch-size' : 256}

estimator_hvd = TensorFlow(base_job_name='hvd-cifar10-tf',
                       source_dir='code',
                       entry_point='train_hvd.py', 
                       role=role,
                       framework_version='1.13',
                       py_version='py3',
                       hyperparameters=hyperparameters,
                       train_instance_count=hvd_instance_count, 
                       train_instance_type=hvd_instance_type,
                       tags = [{'Key' : 'Project', 'Value' : 'cifar10'},{'Key' : 'TensorBoard', 'Value' : 'dist'}],
                       distributions=distributions)

# %% [markdown]
# With these changes to the Estimator, we can call its `fit` method to start training. After training completes, the tf.keras model will be saved in the SavedModel .pb format so it can be served by a TensorFlow Serving container.  Note that the model is only saved by the the master, Horovod rank = 0 process (once again disregard any warnings about the model not being saved by all the processes).

# %%
train_path = 's3://sagemaker-container-webinar/cifar10-dataset/train'
val_path = 's3://sagemaker-container-webinar/cifar10-dataset/validation'
eval_path = 's3://sagemaker-container-webinar/cifar10-dataset/eval'

estimator_hvd.fit({'train': train_path,'validation': val_path,'eval': eval_path}, wait=True)
# Out:
# 2019-08-09 05:53:51 Starting - Starting the training job...
# 2019-08-09 05:53:54 Starting - Launching requested ML instances......
# 2019-08-09 05:55:02 Starting - Preparing the instances for training......
# 2019-08-09 05:56:13 Downloading - Downloading input data
# 2019-08-09 05:56:13 Training - Downloading the training image.....
# 2019-08-09 05:56:56,354 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-08-09 05:56:56,752 sagemaker-containers INFO     Starting MPI run as worker node.
# 2019-08-09 05:56:56,753 sagemaker-containers INFO     Waiting for MPI Master to create SSH daemon.
# 2019-08-09 05:56:56,754 sagemaker-containers INFO     Cannot connect to host algo-1
# 2019-08-09 05:56:56,754 sagemaker-containers INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.0.137.118
# 2019-08-09 05:56:57,760 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.2p2)
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:39: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   m.add_string(self.Q_C.public_numbers().encode_point())
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:96: CryptographyDeprecationWarning: Support for unsafe construction of public numbers from encoded data will be removed in a future version. Please use EllipticCurvePublicKey.from_encoded_point
#   self.curve, Q_S_bytes
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:111: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   hm.add_string(self.Q_C.public_numbers().encode_point())
# 2019-08-09 05:56:57,892 paramiko.transport INFO     Authentication (publickey) successful!
# 2019-08-09 05:56:57,892 sagemaker-containers INFO     Can connect to host algo-1
# 2019-08-09 05:56:57,894 sagemaker-containers INFO     MPI Master online, creating SSH daemon.
# 2019-08-09 05:56:57,900 sagemaker-containers INFO     Waiting for MPI process to finish.
# 2019-08-09 05:56:56,559 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-08-09 05:56:56,933 sagemaker-containers INFO     Starting MPI run as worker node.
# 2019-08-09 05:56:56,933 sagemaker-containers INFO     Creating SSH daemon.
# 2019-08-09 05:56:56,939 sagemaker-containers INFO     Waiting for MPI workers to establish their SSH connections
# 2019-08-09 05:56:56,941 sagemaker-containers INFO     Cannot connect to host algo-2
# 2019-08-09 05:56:56,941 sagemaker-containers INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.0.152.27
# 2019-08-09 05:56:57,947 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.2p2)
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:39: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   m.add_string(self.Q_C.public_numbers().encode_point())
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:96: CryptographyDeprecationWarning: Support for unsafe construction of public numbers from encoded data will be removed in a future version. Please use EllipticCurvePublicKey.from_encoded_point
#   self.curve, Q_S_bytes
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:111: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   hm.add_string(self.Q_C.public_numbers().encode_point())
# 2019-08-09 05:56:58,080 paramiko.transport INFO     Authentication (publickey) successful!
# 2019-08-09 05:56:58,081 sagemaker-containers INFO     Can connect to host algo-2
# 2019-08-09 05:56:58,082 sagemaker-containers INFO     Worker algo-2 available for communication
# 2019-08-09 05:56:58,082 sagemaker-containers INFO     Env Hosts: ['algo-1', 'algo-2'] Hosts: ['algo-1:4', 'algo-2:4'] process_per_hosts: 4 num_processes: 8
# 2019-08-09 05:56:58,084 sagemaker-containers INFO     Network interface name: eth0
# 2019-08-09 05:56:58,133 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_mpi_num_of_processes_per_host": 4,
#         "sagemaker_mpi_custom_mpi_options": "-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none",
#         "sagemaker_mpi_enabled": true
#     },
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "batch-size": 256,
#         "model_dir": "/opt/ml/model",
#         "epochs": 30
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "hvd-cifar10-tf-2019-08-09-05-53-51-233",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-453691756499/hvd-cifar10-tf-2019-08-09-05-53-51-233/source/sourcedir.tar.gz",
#     "module_name": "train_hvd",
#     "network_interface_name": "eth0",
#     "num_cpus": 32,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_hvd.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":256,"epochs":30,"model_dir":"/opt/ml/model"}
# SM_USER_ENTRY_POINT=train_hvd.py
# SM_FRAMEWORK_PARAMS={"sagemaker_mpi_custom_mpi_options":"-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":4}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_hvd
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=32
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-453691756499/hvd-cifar10-tf-2019-08-09-05-53-51-233/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_mpi_custom_mpi_options":"-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":4},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"batch-size":256,"epochs":30,"model_dir":"/opt/ml/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"hvd-cifar10-tf-2019-08-09-05-53-51-233","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-453691756499/hvd-cifar10-tf-2019-08-09-05-53-51-233/source/sourcedir.tar.gz","module_name":"train_hvd","network_interface_name":"eth0","num_cpus":32,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"train_hvd.py"}
# SM_USER_ARGS=["--batch-size","256","--epochs","30","--model_dir","/opt/ml/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH-SIZE=256
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_HP_EPOCHS=30
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python36.zip:/usr/local/lib/python3.6:/usr/local/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# mpirun --host algo-1:4,algo-2:4 -np 8 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -bind-to socket -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/usr/local/lib/python3.6/site-packages/gethostname.cpython-36m-x86_64-linux-gnu.so -verbose -x OMPI_MCA_btl_vader_single_copy_mechanism=none -x SM_HOSTS -x SM_NETWORK_INTERFACE_NAME -x SM_HPS -x SM_USER_ENTRY_POINT -x SM_FRAMEWORK_PARAMS -x SM_RESOURCE_CONFIG -x SM_INPUT_DATA_CONFIG -x SM_OUTPUT_DATA_DIR -x SM_CHANNELS -x SM_CURRENT_HOST -x SM_MODULE_NAME -x SM_LOG_LEVEL -x SM_FRAMEWORK_MODULE -x SM_INPUT_DIR -x SM_INPUT_CONFIG_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_NUM_GPUS -x SM_MODEL_DIR -x SM_MODULE_DIR -x SM_TRAINING_ENV -x SM_USER_ARGS -x SM_OUTPUT_INTERMEDIATE_DIR -x SM_CHANNEL_EVAL -x SM_CHANNEL_VALIDATION -x SM_CHANNEL_TRAIN -x SM_HP_BATCH-SIZE -x SM_HP_MODEL_DIR -x SM_HP_EPOCHS -x PYTHONPATH /usr/local/bin/python3.6 -m mpi4py train_hvd.py --batch-size 256 --epochs 30 --model_dir /opt/ml/model
#
#
# Warning: Permanently added 'algo-2,10.0.152.27' (ECDSA) to the list of known hosts.#015
# --------------------------------------------------------------------------
# WARNING: a request was made to bind a process. While the system
#  Data for JOB [39462,1] offset 0 Total slots allocated 8
#
#  ========================   JOB MAP   ========================
#
#  Data for node: ip-10-0-137-118#011Num slots: 4#011Max slots: 0#011Num procs: 4
#  #011Process OMPI jobid: [39462,1] App: 0 Process rank: 0 Bound: UNBOUND
#  #011Process OMPI jobid: [39462,1] App: 0 Process rank: 1 Bound: UNBOUND
#  #011Process OMPI jobid: [39462,1] App: 0 Process rank: 2 Bound: UNBOUND
#  #011Process OMPI jobid: [39462,1] App: 0 Process rank: 3 Bound: UNBOUND
#
#  Data for node: algo-2#011Num slots: 4#011Max slots: 0#011Num procs: 4
#  #011Process OMPI jobid: [39462,1] App: 0 Process rank: 4 Bound: N/A
# supports binding the process itself, at least one node does NOT
# support binding memory to the process location.
#
#   Node:  ip-10-0-137-118
#
# Open MPI uses the "hwloc" library to perform process and memory
# binding. This error message means that hwloc has indicated that
# processor binding support is not available on this machine.
#
# On OS X, processor and memory binding is not available at all (i.e.,
# the OS does not expose this functionality).
#
# On Linux, lack of the functionality can mean that you are on a
# platform where processor and memory affinity is not supported in Linux
# itself, or that hwloc was built without NUMA and/or processor affinity
# support. When building hwloc (which, depending on your Open MPI
# installation, may be embedded in Open MPI itself), it is important to
#  #011Process OMPI jobid: [39462,1] App: 0 Process rank: 5 Bound: N/A
#  #011Process OMPI jobid: [39462,1] App: 0 Process rank: 6 Bound: N/A
#  #011Process OMPI jobid: [39462,1] App: 0 Process rank: 7 Bound: N/A
#
#  =============================================================
# have the libnuma header and library files available. Different linux
# distributions package these files under different names; look for
# packages with the word "numa" in them. You may also need a developer
# version of the package (e.g., with "dev" or "devel" in the name) to
# obtain the relevant header files.
#
# If you are getting this message on a non-OS X, non-Linux platform,
# then hwloc does not support processor / memory affinity on this
# platform. If the OS/platform does actually support processor / memory
# affinity, then you should contact the hwloc maintainers:
# https://github.com/open-mpi/hwloc.
#
# This is a warning only; your job will continue, though performance may
# be degraded.
# --------------------------------------------------------------------------
# [1,3]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-west-2-453691756499/hvd-cifar10-tf-2019-08-09-05-53-51-233/model
# [1,4]<stderr>:mkdir: cannot create directory ‘/opt/ml/model/code’: File exists
# [1,5]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-west-2-453691756499/hvd-cifar10-tf-2019-08-09-05-53-51-233/model
# [1,4]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-west-2-453691756499/hvd-cifar10-tf-2019-08-09-05-53-51-233/model
# [1,2]<stderr>:mkdir: cannot create directory ‘/opt/ml/model/code’[1,2]<stderr>:: File exists
# [1,6]<stderr>:mkdir: cannot create directory ‘/opt/ml/model/code’[1,6]<stderr>:: File exists
# [1,0]<stderr>:mkdir: cannot create directory ‘/opt/ml/model/code’[1,0]<stderr>:: File exists
# [1,2]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-west-2-453691756499/hvd-cifar10-tf-2019-08-09-05-53-51-233/model
# [1,6]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-west-2-453691756499/hvd-cifar10-tf-2019-08-09-05-53-51-233/model
# [1,1]<stderr>:mkdir: cannot create directory ‘/opt/ml/model/code’[1,1]<stderr>:: File exists
# [1,0]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-west-2-453691756499/hvd-cifar10-tf-2019-08-09-05-53-51-233/model
# [1,1]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-west-2-453691756499/hvd-cifar10-tf-2019-08-09-05-53-51-233/model
# [1,7]<stderr>:mkdir: cannot create directory ‘/opt/ml/model/code’[1,7]<stderr>:: File exists
# [1,7]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-west-2-453691756499/hvd-cifar10-tf-2019-08-09-05-53-51-233/model
# [1,4]<stderr>:2019-08-09 05:57:02.556212: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,5]<stderr>:2019-08-09 05:57:02.558835: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,6]<stderr>:2019-08-09 05:57:02.559912: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,7]<stderr>:2019-08-09 05:57:02.561261: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,4]<stderr>:2019-08-09 05:57:02.574590: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,6]<stderr>:2019-08-09 05:57:02.581526: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,5]<stderr>:2019-08-09 05:57:02.584544: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,7]<stderr>:2019-08-09 05:57:02.595139: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,4]<stderr>:2019-08-09 05:57:02.611423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,6]<stderr>:2019-08-09 05:57:02.619105: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,5]<stderr>:2019-08-09 05:57:02.619487: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,7]<stderr>:2019-08-09 05:57:02.625504: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,4]<stderr>:2019-08-09 05:57:02.653825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,4]<stderr>:2019-08-09 05:57:02.659465: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x3b05d80 executing computations on platform CUDA. Devices:
# [1,4]<stderr>:2019-08-09 05:57:02.659495: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,4]<stderr>:2019-08-09 05:57:02.659503: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (1): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,4]<stderr>:2019-08-09 05:57:02.659509: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (2): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,4]<stderr>:2019-08-09 05:57:02.659515: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (3): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,6]<stderr>:2019-08-09 05:57:02.660953: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,5]<stderr>:2019-08-09 05:57:02.661699: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,7]<stderr>:2019-08-09 05:57:02.664964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,6]<stderr>:2019-08-09 05:57:02.665431: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x3ae6140 executing computations on platform CUDA. Devices:
# [1,6]<stderr>:2019-08-09 05:57:02.665461: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,6]<stderr>:2019-08-09 05:57:02.665469: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (1): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,6]<stderr>:2019-08-09 05:57:02.665476: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (2): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,6]<stderr>:2019-08-09 05:57:02.665481: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (3): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,5]<stderr>:2019-08-09 05:57:02.665803: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x4991140 executing computations on platform CUDA. Devices:
# [1,5]<stderr>:2019-08-09 05:57:02.665831: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,5]<stderr>:2019-08-09 05:57:02.665839: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (1): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,5]<stderr>:2019-08-09 05:57:02.665846: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (2): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,5]<stderr>:2019-08-09 05:57:02.665851: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (3): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,7]<stderr>:2019-08-09 05:57:02.667335: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x49843f0 executing computations on platform CUDA. Devices:
# [1,7]<stderr>:2019-08-09 05:57:02.667363: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,7]<stderr>:2019-08-09 05:57:02.667372: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (1): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,7]<stderr>:2019-08-09 05:57:02.667378: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (2): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,7]<stderr>:2019-08-09 05:57:02.667384: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (3): Tesla V100-SXM2-16GB, Compute Capability 7.0
# [1,6]<stderr>:2019-08-09 05:57:02.695802: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300050000 Hz
# [1,4]<stderr>:2019-08-09 05:57:02.695799: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300050000 Hz
# [1,5]<stderr>:2019-08-09 05:57:02.695803: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300050000 Hz
# [1,7]<stderr>:2019-08-09 05:57:02.695803: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300050000 Hz
# [1,4]<stderr>:2019-08-09 05:57:02.697955: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x3c04e50 executing computations on platform Host. Devices:
# [1,4]<stderr>:2019-08-09 05:57:02.697981: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# [1,6]<stderr>:2019-08-09 05:57:02.698027: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x3be5180 executing computations on platform Host. Devices:
# [1,6]<stderr>:2019-08-09 05:57:02.698049: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# [1,5]<stderr>:2019-08-09 05:57:02.698084: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x4a90210 executing computations on platform Host. Devices:
# [1,5]<stderr>:2019-08-09 05:57:02.698121: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# [1,7]<stderr>:2019-08-09 05:57:02.698111: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x4a83420 executing computations on platform Host. Devices:
# [1,7]<stderr>:2019-08-09 05:57:02.698132: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# [1,4]<stderr>:2019-08-09 05:57:02.698195: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# [1,4]<stderr>:name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# [1,4]<stderr>:pciBusID: 0000:00:1b.0
# [1,4]<stderr>:totalMemory: 15.75GiB freeMemory: 14.55GiB
# [1,4]<stderr>:2019-08-09 05:57:02.698222: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# [1,7]<stderr>:2019-08-09 05:57:02.698316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# [1,7]<stderr>:name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# [1,7]<stderr>:pciBusID: 0000:00:1e.0
# [1,7]<stderr>:totalMemory: 15.75GiB freeMemory: 14.55GiB
# [1,7]<stderr>:2019-08-09 05:57:02.698340: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 3
# [1,6]<stderr>:2019-08-09 05:57:02.698376: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# [1,6]<stderr>:name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# [1,6]<stderr>:pciBusID: 0000:00:1d.0
# [1,6]<stderr>:totalMemory: 15.75GiB freeMemory: 14.55GiB
# [1,6]<stderr>:2019-08-09 05:57:02.698400: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 2
# [1,5]<stderr>:2019-08-09 05:57:02.698461: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# [1,5]<stderr>:name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# [1,5]<stderr>:pciBusID: 0000:00:1c.0
# [1,5]<stderr>:totalMemory: 15.75GiB freeMemory: 14.55GiB
# [1,5]<stderr>:2019-08-09 05:57:02.698491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 1
# [1,6]<stderr>:2019-08-09 05:57:02.840357: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# [1,6]<stderr>:2019-08-09 05:57:02.840412: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      2
# [1,6]<stderr>:2019-08-09 05:57:02.840422: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 2:   N
# [1,6]<stderr>:2019-08-09 05:57:02.840611: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14137 MB memory) -> physical GPU (device: 2, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1d.0, compute capability: 7.0)
# [1,4]<stderr>:2019-08-09 05:57:02.840898: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# [1,4]<stderr>:2019-08-09 05:57:02.840934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# [1,4]<stderr>:2019-08-09 05:57:02.840943: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# [1,4]<stderr>:2019-08-09 05:57:02.841079: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14137 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1b.0, compute capability: 7.0)
# [1,5]<stderr>:2019-08-09 05:57:02.841356: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# [1,5]<stderr>:2019-08-09 05:57:02.841393: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      1
# [1,5]<stderr>:2019-08-09 05:57:02.841402: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 1:   N
# [1,5]<stderr>:2019-08-09 05:57:02.841567: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14136 MB memory) -> physical GPU (device: 1, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1c.0, compute capability: 7.0)
# [1,7]<stderr>:2019-08-09 05:57:02.842540: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# [1,7]<stderr>:2019-08-09 05:57:02.842577: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      3
# [1,7]<stderr>:2019-08-09 05:57:02.842587: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 3:   N
# [1,7]<stderr>:2019-08-09 05:57:02.842719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14137 MB memory) -> physical GPU (device: 3, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0)
# [1,6]<stderr>:INFO:root:Running with MPI=True
# [1,6]<stderr>:INFO:root:getting data
# [1,4]<stderr>:INFO:root:Running with MPI=True
# [1,4]<stderr>:INFO:root:getting data
# [1,5]<stderr>:INFO:root:Running with MPI=True
# [1,5]<stderr>:INFO:root:getting data
# [1,7]<stderr>:INFO:root:Running with MPI=True
# [1,7]<stderr>:INFO:root:getting data
# [1,1]<stderr>:INFO:root:Running with MPI=True
# [1,1]<stderr>:INFO:root:getting data
# [1,0]<stderr>:INFO:root:Running with MPI=True
# [1,0]<stderr>:INFO:root:getting data
# [1,3]<stderr>:INFO:root:Running with MPI=True
# [1,3]<stderr>:INFO:root:getting data
# [1,2]<stderr>:INFO:root:Running with MPI=True
# [1,2]<stderr>:INFO:root:getting data
# [1,5]<stderr>:INFO:root:configuring model
# [1,7]<stderr>:INFO:root:configuring model
# [1,4]<stderr>:INFO:root:configuring model
# [1,6]<stderr>:INFO:root:configuring model
# [1,3]<stderr>:INFO:root:configuring model
# [1,2]<stderr>:INFO:root:configuring model
# [1,0]<stderr>:INFO:root:configuring model
# [1,1]<stderr>:INFO:root:configuring model
# [ip-10-0-137-118.us-west-2.compute.internal:00095] 1 more process has sent help message help-orte-rmaps-base.txt / rmaps:membind-not-supported
# [ip-10-0-137-118.us-west-2.compute.internal:00095] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# [1,5]<stderr>:INFO:root:Starting training
# [1,4]<stderr>:INFO:root:Starting training
# [1,7]<stderr>:INFO:root:Starting training
# [1,6]<stderr>:INFO:root:Starting training
# [1,2]<stderr>:INFO:root:Starting training
# [1,3]<stderr>:INFO:root:Starting training
# [1,1]<stderr>:INFO:root:Starting training
# [1,0]<stderr>:INFO:root:Starting training
#
# 2019-08-09 05:56:53 Training - Training image download completed. Training in progress.[1,6]<stdout>:Epoch 1/30
# [1,1]<stdout>:Epoch 1/30
# [1,0]<stdout>:Epoch 1/30
# [1,7]<stdout>:Epoch 1/30
# [1,4]<stdout>:Epoch 1/30
# [1,3]<stdout>:Epoch 1/30
# [1,5]<stdout>:Epoch 1/30
# [1,2]<stdout>:Epoch 1/30
# [1,4]<stderr>:2019-08-09 05:57:09.882440: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# [1,6]<stderr>:2019-08-09 05:57:09.882440: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# [1,7]<stderr>:2019-08-09 05:57:09.906375: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# [1,5]<stderr>:2019-08-09 05:57:09.907296: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO NET/Socket : Using [0]eth0:10.0.137.118<0>
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,0]<stdout>:
# [1,0]<stdout>:algo-1:101:394 [0] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,0]<stdout>:NCCL version 2.4.7+cuda10.0
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO NET/Socket : Using [0]eth0:10.0.137.118<0>
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO NET/Socket : Using [0]eth0:10.0.137.118<0>
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO NET/Socket : Using [0]eth0:10.0.137.118<0>
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,3]<stdout>:
# [1,3]<stdout>:algo-1:104:384 [3] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,1]<stdout>:
# [1,1]<stdout>:algo-1:102:398 [1] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,2]<stdout>:
# [1,2]<stdout>:algo-1:103:390 [2] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO NET/Socket : Using [0]eth0:10.0.152.27<0>
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO NET/Socket : Using [0]eth0:10.0.152.27<0>
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO NET/Socket : Using [0]eth0:10.0.152.27<0>
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO NET/Socket : Using [0]eth0:10.0.152.27<0>
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,4]<stdout>:
# [1,4]<stdout>:algo-2:108:390 [0] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,7]<stdout>:
# [1,7]<stdout>:algo-2:111:405 [3] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,5]<stdout>:
# [1,5]<stdout>:algo-2:109:391 [1] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,6]<stdout>:
# [1,6]<stdout>:algo-2:110:392 [2] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Setting affinity for GPU 0 to ffffffff
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO Setting affinity for GPU 3 to ffffffff
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO Setting affinity for GPU 1 to ffffffff
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO Setting affinity for GPU 2 to ffffffff
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO Setting affinity for GPU 2 to ffffffff
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO Setting affinity for GPU 1 to ffffffff
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Setting affinity for GPU 0 to ffffffff
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO Setting affinity for GPU 3 to ffffffff
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO CUDA Dev 0[0], Socket NIC distance :  PHB
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO CUDA Dev 1[1], Socket NIC distance :  PHB
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO CUDA Dev 3[3], Socket NIC distance :  PHB
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO CUDA Dev 2[2], Socket NIC distance :  PHB
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO CUDA Dev 1[1], Socket NIC distance :  PHB
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO CUDA Dev 0[0], Socket NIC distance :  PHB
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO CUDA Dev 3[3], Socket NIC distance :  PHB
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO CUDA Dev 2[2], Socket NIC distance :  PHB
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Duplicating rings to 4 per user request.
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Channel 00 :    0   1   2   3   4   5   6   7
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Channel 01 :    0   1   2   3   4   5   6   7
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Channel 02 :    0   1   2   3   4   5   6   7
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Channel 03 :    0   1   2   3   4   5   6   7
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 00 : 3 -> 4 [receive] via NET/Socket/0
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 00 : 7 -> 0 [receive] via NET/Socket/0
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 00 : 4[0] -> 5[1] via P2P/IPC
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 00 : 0[0] -> 1[1] via P2P/IPC
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO Ring 00 : 1[1] -> 2[2] via P2P/IPC
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO Ring 00 : 5[1] -> 6[2] via P2P/IPC
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO Ring 00 : 2[2] -> 3[3] via P2P/IPC
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO Ring 00 : 6[2] -> 7[3] via P2P/IPC
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO Ring 00 : 3 -> 4 [send] via NET/Socket/0
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO Ring 00 : 7 -> 0 [send] via NET/Socket/0
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO Ring 00 : 3[3] -> 2[2] via P2P/IPC
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO Ring 00 : 7[3] -> 6[2] via P2P/IPC
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO Ring 00 : 1[1] -> 0[0] via P2P/IPC
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO Ring 00 : 5[1] -> 4[0] via P2P/IPC
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO Ring 00 : 2[2] -> 1[1] via P2P/IPC
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO Ring 00 : 6[2] -> 5[1] via P2P/IPC
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 00 : 4 -> 0 [receive] via NET/Socket/0
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 00 : 4 -> 0 [send] via NET/Socket/0
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 00 : 0 -> 4 [receive] via NET/Socket/0
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO Ring 01 : 1[1] -> 2[2] via P2P/IPC
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO Ring 01 : 5[1] -> 6[2] via P2P/IPC
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO Ring 01 : 2[2] -> 3[3] via P2P/IPC
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO Ring 01 : 3 -> 4 [send] via NET/Socket/0
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO Ring 01 : 6[2] -> 7[3] via P2P/IPC
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO Ring 01 : 7 -> 0 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 00 : 0 -> 4 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 01 : 7 -> 0 [receive] via NET/Socket/0
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 01 : 3 -> 4 [receive] via NET/Socket/0
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO Ring 01 : 2[2] -> 1[1] via P2P/IPC
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO Ring 01 : 6[2] -> 5[1] via P2P/IPC
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 01 : 0[0] -> 1[1] via P2P/IPC
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO Ring 01 : 3[3] -> 2[2] via P2P/IPC
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 01 : 4[0] -> 5[1] via P2P/IPC
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO Ring 01 : 7[3] -> 6[2] via P2P/IPC
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO Ring 01 : 1[1] -> 0[0] via P2P/IPC
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 01 : 4 -> 0 [receive] via NET/Socket/0
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO Ring 01 : 5[1] -> 4[0] via P2P/IPC
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO Ring 02 : 3 -> 4 [send] via NET/Socket/0
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO Ring 02 : 2[2] -> 3[3] via P2P/IPC
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 01 : 4 -> 0 [send] via NET/Socket/0
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO Ring 02 : 7 -> 0 [send] via NET/Socket/0
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO Ring 02 : 6[2] -> 7[3] via P2P/IPC
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO Ring 02 : 1[1] -> 2[2] via P2P/IPC
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 01 : 0 -> 4 [receive] via NET/Socket/0
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO Ring 02 : 5[1] -> 6[2] via P2P/IPC
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 01 : 0 -> 4 [send] via NET/Socket/0
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO Ring 02 : 2[2] -> 1[1] via P2P/IPC
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO Ring 02 : 6[2] -> 5[1] via P2P/IPC
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 02 : 7 -> 0 [receive] via NET/Socket/0
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 02 : 3 -> 4 [receive] via NET/Socket/0
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 02 : 0[0] -> 1[1] via P2P/IPC
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 02 : 4[0] -> 5[1] via P2P/IPC
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO Ring 02 : 7[3] -> 6[2] via P2P/IPC
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO Ring 02 : 3[3] -> 2[2] via P2P/IPC
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 02 : 0 -> 4 [receive] via NET/Socket/0
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO Ring 02 : 1[1] -> 0[0] via P2P/IPC
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO Ring 02 : 5[1] -> 4[0] via P2P/IPC
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 02 : 0 -> 4 [send] via NET/Socket/0
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO Ring 03 : 7 -> 0 [send] via NET/Socket/0
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO Ring 03 : 6[2] -> 7[3] via P2P/IPC
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO Ring 03 : 3 -> 4 [send] via NET/Socket/0
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO Ring 03 : 2[2] -> 3[3] via P2P/IPC
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 02 : 4 -> 0 [receive] via NET/Socket/0
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO Ring 03 : 5[1] -> 6[2] via P2P/IPC
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO Ring 03 : 1[1] -> 2[2] via P2P/IPC
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 02 : 4 -> 0 [send] via NET/Socket/0
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO Ring 03 : 2[2] -> 1[1] via P2P/IPC
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 03 : 7 -> 0 [receive] via NET/Socket/0
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 03 : 3 -> 4 [receive] via NET/Socket/0
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO Ring 03 : 6[2] -> 5[1] via P2P/IPC
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 03 : 0[0] -> 1[1] via P2P/IPC
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO Ring 03 : 7[3] -> 6[2] via P2P/IPC
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 03 : 4[0] -> 5[1] via P2P/IPC
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO Ring 03 : 3[3] -> 2[2] via P2P/IPC
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO Trees [0] 6->7->-1/-1/-1 [1] 6->7->-1/-1/-1 [2] 6->7->-1/-1/-1 [3] 6->7->-1/-1/-1
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO Trees [0] 2->3->-1/-1/-1 [1] 2->3->-1/-1/-1 [2] 2->3->-1/-1/-1 [3] 2->3->-1/-1/-1
# [1,7]<stdout>:algo-2:111:405 [3] NCCL INFO comm 0x7fe1dc300a80 rank 7 nranks 8 cudaDev 3 nvmlDev 3 - Init COMPLETE
# [1,3]<stdout>:algo-1:104:384 [3] NCCL INFO comm 0x7f95d82f88d0 rank 3 nranks 8 cudaDev 3 nvmlDev 3 - Init COMPLETE
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO Trees [0] 1->2->3/-1/-1 [1] 1->2->3/-1/-1 [2] 1->2->3/-1/-1 [3] 1->2->3/-1/-1
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO Trees [0] 5->6->7/-1/-1 [1] 5->6->7/-1/-1 [2] 5->6->7/-1/-1 [3] 5->6->7/-1/-1
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO Ring 03 : 5[1] -> 4[0] via P2P/IPC
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO Ring 03 : 1[1] -> 0[0] via P2P/IPC
# [1,6]<stdout>:algo-2:110:392 [2] NCCL INFO comm 0x7feba82f8e90 rank 6 nranks 8 cudaDev 2 nvmlDev 2 - Init COMPLETE
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 03 : 0 -> 4 [receive] via NET/Socket/0
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO Trees [0] 4->5->6/-1/-1 [1] 4->5->6/-1/-1 [2] 4->5->6/-1/-1 [3] 4->5->6/-1/-1
# [1,2]<stdout>:algo-1:103:390 [2] NCCL INFO comm 0x7f0b582f2010 rank 2 nranks 8 cudaDev 2 nvmlDev 2 - Init COMPLETE
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO Trees [0] 0->1->2/-1/-1 [1] 0->1->2/-1/-1 [2] 0->1->2/-1/-1 [3] 0->1->2/-1/-1
# [1,5]<stdout>:algo-2:109:391 [1] NCCL INFO comm 0x7f44b02dec30 rank 5 nranks 8 cudaDev 1 nvmlDev 1 - Init COMPLETE
# [1,1]<stdout>:algo-1:102:398 [1] NCCL INFO comm 0x7f43102e64f0 rank 1 nranks 8 cudaDev 1 nvmlDev 1 - Init COMPLETE
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 03 : 0 -> 4 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Ring 03 : 4 -> 0 [receive] via NET/Socket/0
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Ring 03 : 4 -> 0 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Trees [0] -1->0->1/4/-1 [1] -1->0->1/4/-1 [2] 4->0->1/-1/-1 [3] 4->0->1/-1/-1
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Using 256 threads, Min Comp Cap 7, Trees enabled for all sizes
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO Trees [0] 0->4->5/-1/-1 [1] 0->4->5/-1/-1 [2] -1->4->5/0/-1 [3] -1->4->5/0/-1
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO comm 0x7f65f8316560 rank 0 nranks 8 cudaDev 0 nvmlDev 0 - Init COMPLETE
# [1,4]<stdout>:algo-2:108:390 [0] NCCL INFO comm 0x7f861031c550 rank 4 nranks 8 cudaDev 0 nvmlDev 0 - Init COMPLETE
# [1,0]<stdout>:algo-1:101:394 [0] NCCL INFO Launch mode Parallel
# ...
# [1,4]<stdout>:19/19 [==============================] - 2s 98ms/step - loss: 0.5799 - acc: 0.8009 - val_loss: 0.5789 - val_acc: 0.8091
# [1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,5]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,6]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,3]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,5]<stdout>:19/19 [==============================] - 2s 98ms/step - loss: 0.5843 - acc: 0.8009 - val_loss: 0.5789 - val_acc: 0.8091
# [1,6]<stdout>:19/19 [==============================] - 2s 98ms/step - loss: 0.5871 - acc: 0.8009 - val_loss: 0.5789 - val_acc: 0.8091
# [1,1]<stdout>:19/19 [==============================] - 2s 98ms/step - loss: 0.6098 - acc: 0.8009 - val_loss: 0.5789 - val_acc: 0.8091
# [1,3]<stdout>:19/19 [==============================] - 2s 97ms/step - loss: 0.5724 - acc: 0.8009 - val_loss: 0.5789 - val_acc: 0.8091
# [1,2]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,2]<stdout>:19/19 [==============================] - 2s 98ms/step - loss: 0.5812 - acc: 0.8009 - val_loss: 0.5789 - val_acc: 0.8091
# [1,7]<stdout>:Epoch 30/30
# [1,4]<stdout>:Epoch 30/30
# [1,3]<stdout>:Epoch 30/30
# [1,1]<stdout>:Epoch 30/30
# [1,5]<stdout>:Epoch 30/30
# [1,6]<stdout>:Epoch 30/30
# [1,2]<stdout>:Epoch 30/30
# [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:19/19 [==============================] - 2s 98ms/step - loss: 0.5923 - acc: 0.8009 - val_loss: 0.5789 - val_acc: 0.8091
# [1,0]<stdout>:Epoch 30/30
# [1,0]<stdout>:#015[1,3]<stdout>:#015[1,0]<stdout>: 1/19 [>.............................] - ETA: 0s - loss: 0.4895 - acc: 0.8438[1,3]<stdout>: 1/19 [>.............................] - ETA: 4s - loss: 0.5545 - acc: 0.8242[1,1]<stdout>:#015[1,4]<stdout>:#015[1,2]<stdout>:#015[1,4]<stdout>: 1/19 [>.............................] - ETA: 4s - loss: 0.4741 - acc: 0.8477[1,1]<stdout>: 1/19 [>.............................] - ETA: 4s - loss: 0.4992 - acc: 0.8164[1,2]<stdout>: 1/19 [>.............................] - ETA: 4s - loss: 0.4887 - acc: 0.8438[1,5]<stdout>:#015[1,6]<stdout>:#015[1,5]<stdout>: 1/19 [>.............................] - ETA: 4s - loss: 0.5659 - acc: 0.8008[1,7]<stdout>:#015[1,6]<stdout>: 1/19 [>.............................] - ETA: 4s - loss: 0.5193 - acc: 0.7930[1,7]<stdout>: 1/19 [>.............................] - ETA: 4s - loss: 0.6094 - acc: 0.7891[1,3]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,3]<stdout>: 2/19 [==>...........................] - ETA: 2s - loss: 0.5586 - acc: 0.8262[1,2]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,6]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,4]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,7]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2/19 [==>...........................] - ETA: 2s - loss: 0.6140 - acc: 0.7910[1,5]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,6]<stdout>: 2/19 [==>...........................] - ETA: 2s - loss: 0.5402 - acc: 0.8027[1,4]<stdout>: 2/19 [==>...........................] - ETA: 2s - loss: 0.5321 - acc: 0.8281[1,5]<stdout>: 2/19 [==>...........................] - ETA: 2s - loss: 0.5519 - acc: 0.8066[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2/19 [==>...........................] - ETA: 2s - loss: 0.5229 - acc: 0.8184[1 ...
# out>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:12/19 [=================>............] - ETA: 0s - loss: 0.5614 - acc: 0.8102[1,4]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,5]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,4]<stdout>:12/19 [=================>............] - ETA: 0s - loss: 0.5746 - acc: 0.8099[1,5]<stdout>:12/19 [=================>............] - ETA: 0s - loss: 0.5838 - acc: 0.8021[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,3]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:13/19 [===================>..........] - ETA: 0s - loss: 0.5769 - acc: 0.7987[1,0]<stdout>:13/19 [===================>..........] - ETA: 0s - loss: 0.5644 - acc: 0.8110[1,6]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,7]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,3]<stdout>:13/19 [===================>..........] - ETA: 0s - loss: 0.5698 - acc: 0.8047[1,5]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,6]<stdout>:13/19 [===================>..........] - ETA: 0s - loss: 0.5843 - acc: 0.7954[1,5]<stdout>:13/19 [===================>..........] - ETA: 0s - loss: 0.5773 - acc: 0.8041[1,7]<stdout>:13/19 [===================>..........] - ETA: 0s - loss: 0.5644 - acc: 0.8125[1,4]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# [1,2]<stdout>:19/19 [==============================] - 2s 100ms/step - loss: 0.5582 - acc: 0.8064 - val_loss: 0.6123 - val_acc: 0.7964
# [1,3]<stdout>:19/19 [==============================] - 2s 100ms/step - loss: 0.5789 - acc: 0.8064 - val_loss: 0.6123 - val_acc: 0.7964
# [1,7]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,6]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,4]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,5]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,7]<stdout>:19/19 [==============================] - 2s 100ms/step - loss: 0.5673 - acc: 0.8064 - val_loss: 0.6123 - val_acc: 0.7964
# [1,4]<stdout>:19/19 [==============================] - 2s 100ms/step - loss: 0.5814 - acc: 0.8064 - val_loss: 0.6123 - val_acc: 0.7964
# [1,5]<stdout>:19/19 [==============================] - 2s 100ms/step - loss: 0.5723 - acc: 0.8064 - val_loss: 0.6123 - val_acc: 0.7964
# [1,6]<stdout>:19/19 [==============================] - 2s 100ms/step - loss: 0.5726 - acc: 0.8064 - val_loss: 0.6123 - val_acc: 0.7964
# [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:19/19 [==============================] - 2s 106ms/step - loss: 0.5559 - acc: 0.8064 - val_loss: 0.6123 - val_acc: 0.7964
# [1,1]<stderr>:INFO:root:Test loss:0.6267222471726246
# [1,1]<stderr>:INFO:root:Test accuracy:0.7857571840286255
# [1,2]<stderr>:INFO:root:Test loss:0.6302645198809795
# [1,2]<stderr>:INFO:root:Test accuracy:0.7804487347602844
# [1,3]<stderr>:INFO:root:Test loss:0.6323238259706742
# [1,3]<stderr>:INFO:root:Test accuracy:0.7841546535491943
# [1,7]<stderr>:INFO:root:Test loss:0.6272418086345379
# [1,7]<stderr>:INFO:root:Test accuracy:0.7853565812110901
# [1,6]<stderr>:INFO:root:Test loss:0.6339210707407731
# [1,6]<stderr>:INFO:root:Test accuracy:0.78515625
# [1,4]<stderr>:INFO:root:Test loss:0.6343677105047764
# [1,4]<stderr>:INFO:root:Test accuracy:0.7831530570983887
# [1,5]<stderr>:INFO:root:Test loss:0.6329977466509893
# [1,5]<stderr>:INFO:root:Test accuracy:0.7823517918586731
# [1,0]<stderr>:INFO:root:Test loss:0.6279763151437808
# [1,0]<stderr>:INFO:root:Test accuracy:0.7876602411270142
# [1,0]<stdout>:
# [1,0]<stdout>:WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# [1,0]<stdout>:For more information, please see:
# [1,0]<stdout>:  * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
# [1,0]<stdout>:  * https://github.com/tensorflow/addons
# [1,0]<stdout>:If you depend on functionality not listed there, please file an issue.
# [1,0]<stdout>:
# [1,0]<stderr>:INFO:root:Model successfully saved at: /opt/ml/model
# 2019-08-09 05:58:23,567 sagemaker-containers INFO     Reporting training SUCCESS
# 2019-08-09 05:58:53,596 sagemaker-containers INFO     MPI process finished.
# 2019-08-09 05:58:53,596 sagemaker_tensorflow_container.training WARNING  Your model will NOT be servable with SageMaker TensorFlow Serving container.The model artifact was not saved in the TensorFlow SavedModel directory structure:
# https://www.tensorflow.org/guide/saved_model#structure_of_a_savedmodel_directory
# 2019-08-09 05:58:53,596 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2019-08-09 05:59:16 Uploading - Uploading generated training model
# 2019-08-09 05:59:16 Completed - Training job completed
# Billable seconds: 391

# %%
import matplotlib.pyplot as plt

def plot_training_curves(history): 
    
    fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharex=True)
    ax = axes[0]
    ax.plot(history['acc'], label='train')
    ax.plot(history['val_acc'], label='validation')
    ax.set(
        title='model accuracy',
        ylabel='accuracy',
        xlabel='epoch')
    ax.legend()

    ax = axes[1]
    ax.plot(history['loss'], label='train')
    ax.plot(history['val_loss'], label='validation')
    ax.set(
        title='model loss',
        ylabel='loss',
        xlabel='epoch')
    ax.legend()
    fig.tight_layout()

# %% [markdown]
# We can now plot training curves for the Horovod training job similar to the curves we plotted for the parameter servers training job:

# %%
import json
# !aws s3 cp {estimator_hvd.model_data} ./hvd_model/model.tar.gz
# !tar -xzf ./hvd_model/model.tar.gz -C ./hvd_model

with open('./hvd_model/hvd_history.p', "r") as f:
    hvd_history = json.load(f)
    
plot_training_curves(hvd_history)
